# %%
import json
from datetime import datetime
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import torch
import torch.nn as nn
from torch.cuda.amp import GradScaler
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader, Dataset

from constants import ASTEROIDS_DIR, DATA_DIR, MODELS_DIR
from src.model import Asteroid, Lightcurve
from src.utils import LightcurveBinner

sns.set_theme(style="darkgrid")
plt.rcParams["figure.figsize"] = (14, 6)

# %%
PERIOD_FILE = "period.txt"
C_G_S = "\033[1;32m"
C_Y_S = "\033[1;33m"
C_E = "\033[0m"

# %%
ASTEROIDS_DF = pd.read_csv(DATA_DIR / "asteroids.csv", index_col=0)
ASTEROIDS_DF = ASTEROIDS_DF.dropna(subset=["number"])
ASTEROIDS_DF["number"] = ASTEROIDS_DF["number"].astype(int)
ASTEROIDS_DF
# Out:
#       number     name designation         comment              created  \
# id
# 3414       1    Ceres         NaN  albedo effects  2021-11-18 10:13:38
# 101        2   Pallas         NaN             NaN                  NaN
# 102        3     Juno         NaN             NaN                  NaN
# 3415       4    Vesta         NaN  albedo effects  2021-11-19 11:18:10
# 103        5  Astraea         NaN             NaN                  NaN
# ...      ...      ...         ...             ...                  ...
# 7103  353971      NaN         NaN             NaN  2023-05-23 07:51:09
# 7110  354510      NaN         NaN             NaN  2023-05-23 07:51:09
# 7194  362935      NaN         NaN             NaN  2023-05-23 07:51:13
# 7320  380282      NaN         NaN             NaN  2023-05-23 07:51:18
# 7456  397797      NaN         NaN             NaN  2023-05-23 07:51:23
#
#                  modified
# id
# 3414  2021-11-18 10:14:01
# 101   2019-05-31 11:22:28
# 102   2010-04-15 15:54:09
# 3415  2021-11-19 11:27:06
# 103   2010-04-15 15:54:09
# ...                   ...
# 7103  2023-05-23 07:51:09
# 7110  2023-05-23 07:51:09
# 7194  2023-05-23 07:51:13
# 7320  2023-05-23 07:51:18
# 7456  2023-05-23 07:51:23
#
# [10751 rows x 6 columns]

# %%
AVAILABLE_ASTEROIDS = {}
for directory in ASTEROIDS_DIR.iterdir():
    if not directory.is_dir():
        continue

    asteroid_name = directory.name.split("_")[0]
    work_name = directory.name

    res = ASTEROIDS_DF.query(f"name == '{asteroid_name}'")
    if len(res) != 1:
        raise ValueError(f"Found multiple asteroids with name {asteroid_name} (work name: {work_name})")

    (asteroid_num,) = res["number"]

    if not (directory / PERIOD_FILE).exists():
        raise FileNotFoundError(f"Missing {PERIOD_FILE} for {work_name}")
    
    with open(directory / PERIOD_FILE, "r") as f:
        period = float(f.read().strip())
    
    AVAILABLE_ASTEROIDS[work_name] = {"id": asteroid_num, "name": asteroid_name, "period": period}

AVAILABLE_ASTEROIDS = {k: AVAILABLE_ASTEROIDS[k] for k in sorted(AVAILABLE_ASTEROIDS)}
AVAILABLE_ASTEROIDS
# Out:
# {'Aegina': {'id': 91, 'name': 'Aegina', 'period': 6.02817},
#  'Aglaja': {'id': 47, 'name': 'Aglaja', 'period': 13.17707},
#  'Alexandra': {'id': 54, 'name': 'Alexandra', 'period': 7.02264},
#  'Alkmene': {'id': 82, 'name': 'Alkmene', 'period': 13.00079},
#  'Amphitrite': {'id': 29, 'name': 'Amphitrite', 'period': 5.39012},
#  'Angelina': {'id': 64, 'name': 'Angelina', 'period': 8.75033},
#  'Arethusa': {'id': 95, 'name': 'Arethusa', 'period': 8.70221},
#  'Ariadne': {'id': 43, 'name': 'Ariadne', 'period': 5.761987},
#  'Asia': {'id': 67, 'name': 'Asia', 'period': 15.8515},
#  'Astraea': {'id': 5, 'name': 'Astraea', 'period': 16.80059},
#  'Atalante': {'id': 36, 'name': 'Atalante', 'period': 9.92692},
#  'Aurora': {'id': 94, 'name': 'Aurora', 'period': 7.226189},
#  'Ausonia': {'id': 63, 'name': 'Ausonia', 'period': 9.29759},
#  'Beatrix': {'id': 83, 'name': 'Beatrix', 'period': 10.1107},
#  'Bellona': {'id': 28, 'name': 'Bellona', 'period': 15.70785},
#  'Ceres': {'id': 1, 'name': 'Ceres', 'period': 9.074173},
#  'Circe': {'id': 34, 'name': 'Circe', 'period': 12.17458},
#  'Cybele': {'id': 65, 'name': 'Cybele', 'period': 6.081435},
#  'Daphne': {'id': 41, 'name': 'Daphne', 'period': 5.987981},
#  'Dike': {'id': 99, 'name': 'Dike', 'period': 18.11914},
#  'Doris': {'id': 48, 'name': 'Doris', 'period': 11.8901},
#  'Echo': {'id': 60, 'name': 'Echo', 'period': 25.2285},
#  'Egeria': {'id': 13, 'name': 'Egeria', 'period': 7.046665},
#  'Elpis': {'id': 59, 'name': 'Elpis', 'period': 13.6747},
#  'Erato': {'id': 62, 'name': 'Erato', 'period': 9.2182},
#  'Eros': {'id': 433, 'name': 'Eros', 'period': 5.27025528},
#  'Eugenia': {'id': 45, 'name': 'Eugenia', 'period': 5.699152},
#  'Eunomia': {'id': 15, 'name': 'Eunomia', 'period': 6.082754},
#  'Euphrosyne': {'id': 31, 'name': 'Euphrosyne', 'period': 5.529594},
#  'Europa': {'id': 52, 'name': 'Europa', 'period': 5.629959},
#  'Eurynome': {'id': 79, 'name': 'Eurynome', 'period': 5.977722},
#  'Euterpe': {'id': 27, 'name': 'Euterpe', 'period': 10.40828},
#  'Feronia': {'id': 72, 'name': 'Feronia', 'period': 8.09068},
#  'Fides': {'id': 37, 'name': 'Fides', 'period': 7.332527},
#  'Flora': {'id': 8, 'name': 'Flora', 'period': 12.86667},
#  'Fortuna': {'id': 19, 'name': 'Fortuna', 'period': 7.443224},
#  'Freia': {'id': 76, 'name': 'Freia', 'period': 9.97306},
#  'Galatea': {'id': 74, 'name': 'Galatea', 'period': 17.2675},
#  'Harmonia': {'id': 40, 'name': 'Harmonia', 'period': 8.908485},
#  'Hebe': {'id': 6, 'name': 'Hebe', 'period': 7.274467},
#  'Hesperia': {'id': 69, 'name': 'Hesperia', 'period': 5.65534},
#  'Hestia': {'id': 46, 'name': 'Hestia', 'period': 21.0401},
#  'Hygiea': {'id': 10, 'name': 'Hygiea', 'period': 13.82559},
#  'Ianthe': {'id': 98, 'name': 'Ianthe', 'period': 16.48013},
#  'Interamnia': {'id': 704, 'name': 'Interamnia', 'period': 8.712337},
#  'Io': {'id': 85, 'name': 'Io', 'period': 6.874784},
#  'Irene': {'id': 14, 'name': 'Irene', 'period': 15.02987},
#  'Iris': {'id': 7, 'name': 'Iris', 'period': 7.138844},
#  'Isis': {'id': 42, 'name': 'Isis', 'period': 13.58364},
#  'Julia': {'id': 89, 'name': 'Julia', 'period': 11.388336},
#  'Juno': {'id': 3, 'name': 'Juno', 'period': 7.20953},
#  'Kalliope': {'id': 22, 'name': 'Kalliope', 'period': 4.1482015},
#  'Kalypso': {'id': 53, 'name': 'Kalypso', 'period': 9.03506},
#  'Klio': {'id': 84, 'name': 'Klio', 'period': 23.575},
#  'Klotho': {'id': 97, 'name': 'Klotho', 'period': 35.251},
#  'Klytia': {'id': 73, 'name': 'Klytia', 'period': 8.28307},
#  'Laetitia': {'id': 39, 'name': 'Laetitia', 'period': 5.138238},
#  'Leda': {'id': 38, 'name': 'Leda', 'period': 12.83613},
#  'Leto': {'id': 68, 'name': 'Leto', 'period': 14.84547},
#  'Leukothea': {'id': 35, 'name': 'Leukothea', 'period': 31.9009},
#  'Lutetia': {'id': 21, 'name': 'Lutetia', 'period': 8.168271},
#  'Maja': {'id': 66, 'name': 'Maja', 'period': 9.73572},
#  'Massalia': {'id': 20, 'name': 'Massalia', 'period': 8.09902},
#  'Melete': {'id': 56, 'name': 'Melete', 'period': 18.14818},
#  'Melpomene': {'id': 18, 'name': 'Melpomene', 'period': 11.57031},
#  'Metis': {'id': 9, 'name': 'Metis', 'period': 5.079177},
#  'Minerva': {'id': 93, 'name': 'Minerva', 'period': 5.981768},
#  'Nemausa': {'id': 51, 'name': 'Nemausa', 'period': 7.78484},
#  'Niobe': {'id': 71, 'name': 'Niobe', 'period': 35.8521},
#  'Nysa': {'id': 44, 'name': 'Nysa', 'period': 6.421417},
#  'Pallas': {'id': 2, 'name': 'Pallas', 'period': 7.81322},
#  'Pandora': {'id': 55, 'name': 'Pandora', 'period': 4.804043},
#  'Panopaea': {'id': 70, 'name': 'Panopaea', 'period': 15.80439},
#  'Parthenope': {'id': 11, 'name': 'Parthenope', 'period': 13.72205},
#  'Phocaea': {'id': 25, 'name': 'Phocaea', 'period': 9.935397},
#  'Polyhymnia': {'id': 33, 'name': 'Polyhymnia', 'period': 18.60888},
#  'Pomona': {'id': 32, 'name': 'Pomona', 'period': 9.44767},
#  'Proserpina': {'id': 26, 'name': 'Proserpina', 'period': 13.10977},
#  'Psyche': {'id': 16, 'name': 'Psyche', 'period': 4.195948},
#  'Sappho': {'id': 80, 'name': 'Sappho', 'period': 14.03086},
#  'Semele': {'id': 86, 'name': 'Semele', 'period': 16.642},
#  'Sylvia': {'id': 87, 'name': 'Sylvia', 'period': 5.183641},
#  'Thalia': {'id': 23, 'name': 'Thalia', 'period': 12.31241},
#  'Themis': {'id': 24, 'name': 'Themis', 'period': 8.37419},
#  'Thetis': {'id': 17, 'name': 'Thetis', 'period': 12.26603},
#  'Thisbe': {'id': 88, 'name': 'Thisbe', 'period': 6.041319},
#  'Urania': {'id': 30, 'name': 'Urania', 'period': 13.68717},
#  'Vesta': {'id': 4, 'name': 'Vesta', 'period': 5.342124},
#  'Victoria': {'id': 12, 'name': 'Victoria', 'period': 8.66034},
#  'Virginia': {'id': 50, 'name': 'Virginia', 'period': 14.31233}}

# %%
lightcurve_binner = LightcurveBinner()

# %%
asteroid_name = "Eunomia"  # Interamnia, Eros, Ceres, Eunomia

# %%
def load_asteroid(asteroid_name) -> Asteroid:
    chosen_asteroid = AVAILABLE_ASTEROIDS[asteroid_name]
    asteroid_id, known_period = chosen_asteroid["id"], chosen_asteroid["period"]

    with open(ASTEROIDS_DIR / asteroid_name / "lc.json", "r") as f:
        raw_data = json.load(f)

    asteroid = Asteroid.from_lightcurves(id=asteroid_id, name=asteroid_name, period=known_period, data=raw_data)

    return asteroid

# %%
asteroid = load_asteroid(asteroid_name)
asteroid
# Out:
# Asteroid(id=15, name=Eunomia, period=6.082754, lightcurves=109)

# %%
bins = lightcurve_binner.bin_lightcurves_by_asteroid(asteroid, max_time_diff=30, min_n=3)

# %%
for ind, _bin in enumerate(bins):
    first_JD = _bin[0].first_JD
    last_JD = _bin[-1].last_JD

    duration = last_JD - first_JD
    lc_range = f"{duration:5.2f} days"
    if duration < 1:
        lc_range += f" - {duration * 24:.2f} hours"

    print(
        f"{ind:2} - {C_Y_S}{len(_bin):2}{C_E} lcs from {first_JD:.2f} to {last_JD:.2f} {C_G_S}({lc_range}){C_E}"
    )
# Out:
#  0 -  3 lcs from 2435462.58 to 2435468.70 ( 6.12 days)
#  1 -  3 lcs from 2442103.37 to 2442130.40 (27.04 days)
#  2 -  5 lcs from 2442149.30 to 2442158.36 ( 9.06 days)
#  3 -  6 lcs from 2444912.26 to 2444941.00 (28.74 days)
#  4 -  3 lcs from 2445363.86 to 2445388.76 (24.89 days)
#  5 -  3 lcs from 2445831.84 to 2445858.85 (27.01 days)
#  6 -  4 lcs from 2446345.58 to 2446363.77 (18.19 days)
#  7 -  9 lcs from 2453886.48 to 2453897.63 (11.15 days)
#  8 -  9 lcs from 2454934.46 to 2454964.42 (29.95 days)
#  9 -  8 lcs from 2454965.20 to 2454992.29 (27.10 days)
# 10 - 15 lcs from 2455936.37 to 2455953.49 (17.12 days)
# 11 - 13 lcs from 2456303.62 to 2456327.77 (24.15 days)
# 12 -  4 lcs from 2458284.58 to 2458295.67 (11.09 days)

# %%
# TODO:
# - sprawdzić jak działa LSTM dokładniej i co jest outputem :v
# - poddać krzywe do analizy Fourierowskiej (każda krzywa osobno i dostaję X elementów), może być zrobione w binach
# - przerzucić przez LSTMa i z każdego bina zagregować te wyjścia - na przykład średnią
# - przerzucić to nam sam koniec przez jaką warstwę FC i zwrócić wynik

# %%
for lc in bins:
    print(f"- {len(lc)} lightcurves")
    for points in lc:
        print(f"  - {len(points)} points")
# Out:
# - 3 lightcurves
#   - 66 points
#   - 90 points
#   - 24 points
# - 3 lightcurves
#   - 70 points
#   - 55 points
#   - 29 points
# - 5 lightcurves
#   - 46 points
#   - 20 points
#   - 30 points
#   - 29 points
#   - 21 points
# - 6 lightcurves
#   - 64 points
#   - 44 points
#   - 7 points
#   - 14 points
#   - 33 points
#   - 19 points
# - 3 lightcurves
#   - 6 points
#   - 25 points
#   - 18 points
# - 3 lightcurves
#   - 13 points
#   - 42 points
#   - 11 points
# - 4 lightcurves
#   - 36 points
#   - 37 points
#   - 29 points
#   - 14 points
# - 9 lightcurves
#   - 37 points
#   - 36 points
#   - 45 points
#   - 29 points
#   - 49 points
#   - 54 points
#   - 62 points
#   - 61 points
#   - 113 points
# - 9 lightcurves
#   - 78 points
#   - 116 points
#   - 50 points
#   - 39 points
#   - 46 points
#   - 16 points
#   - 51 points
#   - 57 points
#   - 71 points
# - 8 lightcurves
#   - 48 points
#   - 76 points
#   - 75 points
#   - 61 points
#   - 50 points
#   - 57 points
#   - 67 points
#   - 44 points
# - 15 lightcurves
#   - 226 points
#   - 143 points
#   - 228 points
#   - 193 points
#   - 201 points
#   - 169 points
#   - 212 points
#   - 207 points
#   - 194 points
#   - 145 points
#   - 79 points
#   - 141 points
#   - 183 points
#   - 123 points
#   - 163 points
# - 13 lightcurves
#   - 243 points
#   - 214 points
#   - 259 points
#   - 159 points
#   - 267 points
#   - 192 points
#   - 279 points
#   - 33 points
#   - 315 points
#   - 434 points
#   - 447 points
#   - 356 points
#   - 355 points
# - 4 lightcurves
#   - 70 points
#   - 62 points
#   - 89 points
#   - 121 points

# %%
class AsteroidDataset(Dataset):
    """
    Dataset containing asteroids, each composed of Lightcurve sessions
    """

    def __init__(self, asteroids: list[Asteroid]):
        self.asteroids = self._extract_points(asteroids)
        self.periods = self._extract_periods(asteroids)

    def __len__(self):
        return len(self.asteroids)

    def __getitem__(self, idx):
        return self.asteroids[idx], self.periods[idx]

    def _extract_points(self, asteroids: list[Asteroid]) -> list[list[list[torch.Tensor]]]:
        parsed_asteroids = []
        for asteroid in asteroids:
            bins = lightcurve_binner.bin_lightcurves_by_asteroid(asteroid, max_time_diff=30, min_n=3)
            sessions = []
            for session in bins:
                session_points = []
                for lightcurve in session:
                    data_points = [(point.JD, point.brightness) for point in lightcurve.points]
                    session_points.append(torch.tensor(data_points, dtype=torch.float32))

                sessions.append(session_points)

            parsed_asteroids.append(sessions)

        return parsed_asteroids

    def _extract_periods(self, asteroids: list[Asteroid]) -> list[float]:
        return [asteroid.period for asteroid in asteroids]


def collate_fn(asteroid_batch):
    assert len(asteroid_batch) == 1, "Batch size must be 1"

    asteroid, period = asteroid_batch[0]

    max_lightcurves = max(len(session) for session in asteroid)
    max_points = max(max(lightcurve.size(0) for lightcurve in session) for session in asteroid)

    padded_sessions = []
    for session in asteroid:
        padded_lightcurves = [
            (
                torch.cat([lightcurve, torch.zeros((max_points - lightcurve.size(0), 2))])
                if lightcurve.size(0) < max_points
                else lightcurve
            )
            for lightcurve in session
        ]
        padded_lightcurves = torch.stack(padded_lightcurves)
        num_padding_lightcurves = max_lightcurves - padded_lightcurves.size(0)
        if num_padding_lightcurves > 0:
            padding = torch.zeros((num_padding_lightcurves, max_points, 2))
            padded_lightcurves = torch.cat((padded_lightcurves, padding), dim=0)

        padded_sessions.append(padded_lightcurves)

    padded_asteroid = torch.stack(padded_sessions)
    period_tensor = torch.tensor([period], dtype=torch.float32)

    padded_asteroid = padded_asteroid.unsqueeze(0)  # Add batch dimension

    return padded_asteroid, period_tensor

# %%
asteroids = []
for key in AVAILABLE_ASTEROIDS:
    if key in ("Interamnia", "Eros"):
        continue

    asteroid = load_asteroid(key)
    if len(asteroid.lightcurves) < 10:
        continue

    asteroids.append(asteroid)

asteroids
# Out:
# [Asteroid(id=54, name=Alexandra, period=7.02264, lightcurves=38),
#  Asteroid(id=82, name=Alkmene, period=13.00079, lightcurves=16),
#  Asteroid(id=29, name=Amphitrite, period=5.39012, lightcurves=66),
#  Asteroid(id=64, name=Angelina, period=8.75033, lightcurves=22),
#  Asteroid(id=43, name=Ariadne, period=5.761987, lightcurves=43),
#  Asteroid(id=5, name=Astraea, period=16.80059, lightcurves=25),
#  Asteroid(id=36, name=Atalante, period=9.92692, lightcurves=31),
#  Asteroid(id=94, name=Aurora, period=7.226189, lightcurves=22),
#  Asteroid(id=63, name=Ausonia, period=9.29759, lightcurves=16),
#  Asteroid(id=28, name=Bellona, period=15.70785, lightcurves=24),
#  Asteroid(id=1, name=Ceres, period=9.074173, lightcurves=46),
#  Asteroid(id=34, name=Circe, period=12.17458, lightcurves=17),
#  Asteroid(id=65, name=Cybele, period=6.081435, lightcurves=62),
#  Asteroid(id=41, name=Daphne, period=5.987981, lightcurves=49),
#  Asteroid(id=99, name=Dike, period=18.11914, lightcurves=30),
#  Asteroid(id=48, name=Doris, period=11.8901, lightcurves=32),
#  Asteroid(id=13, name=Egeria, period=7.046665, lightcurves=38),
#  Asteroid(id=45, name=Eugenia, period=5.699152, lightcurves=101),
#  Asteroid(id=15, name=Eunomia, period=6.082754, lightcurves=109),
#  Asteroid(id=31, name=Euphrosyne, period=5.529594, lightcurves=64),
#  Asteroid(id=52, name=Europa, period=5.629959, lightcurves=49),
#  Asteroid(id=79, name=Eurynome, period=5.977722, lightcurves=39),
#  Asteroid(id=27, name=Euterpe, period=10.40828, lightcurves=55),
#  Asteroid(id=72, name=Feronia, period=8.09068, lightcurves=23),
#  Asteroid(id=37, name=Fides, period=7.332527, lightcurves=27),
#  Asteroid(id=8, name=Flora, period=12.86667, lightcurves=54),
#  Asteroid(id=19, name=Fortuna, period=7.443224, lightcurves=48),
#  Asteroid(id=76, name=Freia, period=9.97306, lightcurves=38),
#  Asteroid(id=40, name=Harmonia, period=8.908485, lightcurves=23),
#  Asteroid(id=6, name=Hebe, period=7.274467, lightcurves=142),
#  Asteroid(id=69, name=Hesperia, period=5.65534, lightcurves=38),
#  Asteroid(id=46, name=Hestia, period=21.0401, lightcurves=33),
#  Asteroid(id=10, name=Hygiea, period=13.82559, lightcurves=166),
#  Asteroid(id=98, name=Ianthe, period=16.48013, lightcurves=10),
#  Asteroid(id=85, name=Io, period=6.874784, lightcurves=29),
#  Asteroid(id=14, name=Irene, period=15.02987, lightcurves=33),
#  Asteroid(id=7, name=Iris, period=7.138844, lightcurves=39),
#  Asteroid(id=42, name=Isis, period=13.58364, lightcurves=37),
#  Asteroid(id=89, name=Julia, period=11.388336, lightcurves=37),
#  Asteroid(id=3, name=Juno, period=7.20953, lightcurves=28),
#  Asteroid(id=22, name=Kalliope, period=4.1482015, lightcurves=155),
#  Asteroid(id=53, name=Kalypso, period=9.03506, lightcurves=41),
#  Asteroid(id=97, name=Klotho, period=35.251, lightcurves=28),
#  Asteroid(id=73, name=Klytia, period=8.28307, lightcurves=26),
#  Asteroid(id=39, name=Laetitia, period=5.138238, lightcurves=68),
#  Asteroid(id=38, name=Leda, period=12.83613, lightcurves=30),
#  Asteroid(id=68, name=Leto, period=14.84547, lightcurves=16),
#  Asteroid(id=35, name=Leukothea, period=31.9009, lightcurves=53),
#  Asteroid(id=21, name=Lutetia, period=8.168271, lightcurves=50),
#  Asteroid(id=66, name=Maja, period=9.73572, lightcurves=17),
#  Asteroid(id=20, name=Massalia, period=8.09902, lightcurves=18),
#  Asteroid(id=56, name=Melete, period=18.14818, lightcurves=38),
#  Asteroid(id=18, name=Melpomene, period=11.57031, lightcurves=176),
#  Asteroid(id=9, name=Metis, period=5.079177, lightcurves=38),
#  Asteroid(id=93, name=Minerva, period=5.981768, lightcurves=34),
#  Asteroid(id=51, name=Nemausa, period=7.78484, lightcurves=135),
#  Asteroid(id=71, name=Niobe, period=35.8521, lightcurves=50),
#  Asteroid(id=44, name=Nysa, period=6.421417, lightcurves=72),
#  Asteroid(id=2, name=Pallas, period=7.81322, lightcurves=61),
#  Asteroid(id=55, name=Pandora, period=4.804043, lightcurves=36),
#  Asteroid(id=70, name=Panopaea, period=15.80439, lightcurves=122),
#  Asteroid(id=11, name=Parthenope, period=13.72205, lightcurves=138),
#  Asteroid(id=25, name=Phocaea, period=9.935397, lightcurves=29),
#  Asteroid(id=33, name=Polyhymnia, period=18.60888, lightcurves=49),
#  Asteroid(id=32, name=Pomona, period=9.44767, lightcurves=18),
#  Asteroid(id=26, name=Proserpina, period=13.10977, lightcurves=30),
#  Asteroid(id=16, name=Psyche, period=4.195948, lightcurves=209),
#  Asteroid(id=80, name=Sappho, period=14.03086, lightcurves=16),
#  Asteroid(id=87, name=Sylvia, period=5.183641, lightcurves=41),
#  Asteroid(id=23, name=Thalia, period=12.31241, lightcurves=50),
#  Asteroid(id=24, name=Themis, period=8.37419, lightcurves=112),
#  Asteroid(id=17, name=Thetis, period=12.26603, lightcurves=53),
#  Asteroid(id=88, name=Thisbe, period=6.041319, lightcurves=188),
#  Asteroid(id=30, name=Urania, period=13.68717, lightcurves=18),
#  Asteroid(id=4, name=Vesta, period=5.342124, lightcurves=169),
#  Asteroid(id=12, name=Victoria, period=8.66034, lightcurves=54),
#  Asteroid(id=50, name=Virginia, period=14.31233, lightcurves=45)]

# %%
test_asteroids = [load_asteroid("Interamnia"), load_asteroid("Eros")]
test_asteroids
# Out:
# [Asteroid(id=704, name=Interamnia, period=8.712337, lightcurves=188),
#  Asteroid(id=433, name=Eros, period=5.27025528, lightcurves=118)]

# %%
dataset = AsteroidDataset(asteroids)
data_loader = DataLoader(dataset, batch_size=1, collate_fn=collate_fn)

for batch in data_loader:
    inputs, targets = batch
    print(targets)
    print(inputs.size(), targets.size())
# Out:
# tensor([7.0226])
# torch.Size([1, 8, 5, 345, 2]) torch.Size([1])
# tensor([13.0008])
# torch.Size([1, 2, 6, 15, 2]) torch.Size([1])
# tensor([5.3901])
# torch.Size([1, 9, 9, 174, 2]) torch.Size([1])
# tensor([8.7503])
# torch.Size([1, 4, 6, 74, 2]) torch.Size([1])
# tensor([5.7620])
# torch.Size([1, 8, 9, 149, 2]) torch.Size([1])
# tensor([16.8006])
# torch.Size([1, 3, 7, 44, 2]) torch.Size([1])
# tensor([9.9269])
# torch.Size([1, 4, 11, 369, 2]) torch.Size([1])
# tensor([7.2262])
# torch.Size([1, 3, 4, 42, 2]) torch.Size([1])
# tensor([9.2976])
# torch.Size([1, 2, 5, 331, 2]) torch.Size([1])
# tensor([15.7079])
# torch.Size([1, 4, 6, 381, 2]) torch.Size([1])
# tensor([9.0742])
# torch.Size([1, 7, 8, 465, 2]) torch.Size([1])
# tensor([12.1746])
# torch.Size([1, 3, 8, 220, 2]) torch.Size([1])
# tensor([6.0814])
# torch.Size([1, 10, 6, 467, 2]) torch.Size([1])
# tensor([5.9880])
# torch.Size([1, 7, 7, 651, 2]) torch.Size([1])
# tensor([18.1191])
# torch.Size([1, 4, 10, 402, 2]) torch.Size([1])
# tensor([11.8901])
# torch.Size([1, 2, 17, 233, 2]) torch.Size([1])
# tensor([7.0467])
# torch.Size([1, 4, 10, 469, 2]) torch.Size([1])
# tensor([5.6992])
# torch.Size([1, 17, 9, 416, 2]) torch.Size([1])
# tensor([6.0828])
# torch.Size([1, 13, 15, 447, 2]) torch.Size([1])
# tensor([5.5296])
# torch.Size([1, 5, 35, 396, 2]) torch.Size([1])
# tensor([5.6300])
# torch.Size([1, 6, 10, 298, 2]) torch.Size([1])
# tensor([5.9777])
# torch.Size([1, 5, 8, 196, 2]) torch.Size([1])
# tensor([10.4083])
# torch.Size([1, 7, 14, 270, 2]) torch.Size([1])
# tensor([8.0907])
# torch.Size([1, 4, 8, 196, 2]) torch.Size([1])
# tensor([7.3325])
# torch.Size([1, 5, 7, 135, 2]) torch.Size([1])
# tensor([12.8667])
# torch.Size([1, 9, 6, 318, 2]) torch.Size([1])
# tensor([7.4432])
# torch.Size([1, 10, 6, 196, 2]) torch.Size([1])
# tensor([9.9731])
# torch.Size([1, 7, 5, 121, 2]) torch.Size([1])
# tensor([8.9085])
# torch.Size([1, 5, 5, 436, 2]) torch.Size([1])
# tensor([7.2745])
# torch.Size([1, 13, 27, 200, 2]) torch.Size([1])
# tensor([5.6553])
# torch.Size([1, 3, 20, 45, 2]) torch.Size([1])
# tensor([21.0401])
# torch.Size([1, 6, 7, 481, 2]) torch.Size([1])
# tensor([13.8256])
# torch.Size([1, 19, 15, 1549, 2]) torch.Size([1])
# tensor([16.4801])
# torch.Size([1, 2, 5, 260, 2]) torch.Size([1])
# tensor([6.8748])
# torch.Size([1, 5, 7, 102, 2]) torch.Size([1])
# tensor([15.0299])
# torch.Size([1, 6, 5, 411, 2]) torch.Size([1])
# tensor([7.1388])
# torch.Size([1, 3, 4, 75, 2]) torch.Size([1])
# tensor([13.5836])
# torch.Size([1, 7, 9, 210, 2]) torch.Size([1])
# tensor([11.3883])
# torch.Size([1, 6, 9, 726, 2]) torch.Size([1])
# tensor([7.2095])
# torch.Size([1, 4, 6, 85, 2]) torch.Size([1])
# tensor([4.1482])
# torch.Size([1, 20, 16, 510, 2]) torch.Size([1])
# tensor([9.0351])
# torch.Size([1, 7, 8, 295, 2]) torch.Size([1])
# tensor([35.2510])
# torch.Size([1, 3, 11, 47, 2]) torch.Size([1])
# tensor([8.2831])
# torch.Size([1, 4, 4, 131, 2]) torch.Size([1])
# tensor([5.1382])
# torch.Size([1, 8, 6, 132, 2]) torch.Size([1])
# tensor([12.8361])
# torch.Size([1, 5, 8, 247, 2]) torch.Size([1])
# tensor([14.8455])
# torch.Size([1, 2, 9, 174, 2]) torch.Size([1])
# tensor([31.9009])
# torch.Size([1, 8, 13, 417, 2]) torch.Size([1])
# tensor([8.1683])
# torch.Size([1, 10, 6, 304, 2]) torch.Size([1])
# tensor([9.7357])
# torch.Size([1, 2, 5, 59, 2]) torch.Size([1])
# tensor([8.0990])
# torch.Size([1, 2, 4, 74, 2]) torch.Size([1])
# tensor([18.1482])
# torch.Size([1, 1, 37, 617, 2]) torch.Size([1])
# tensor([11.5703])
# torch.Size([1, 20, 17, 831, 2]) torch.Size([1])
# tensor([5.0792])
# torch.Size([1, 6, 6, 188, 2]) torch.Size([1])
# tensor([5.9818])
# torch.Size([1, 4, 6, 478, 2]) torch.Size([1])
# tensor([7.7848])
# torch.Size([1, 12, 25, 682, 2]) torch.Size([1])
# tensor([35.8521])
# torch.Size([1, 5, 23, 569, 2]) torch.Size([1])
# tensor([6.4214])
# torch.Size([1, 10, 10, 207, 2]) torch.Size([1])
# tensor([7.8132])
# torch.Size([1, 14, 5, 106, 2]) torch.Size([1])
# tensor([4.8040])
# torch.Size([1, 4, 8, 120, 2]) torch.Size([1])
# tensor([15.8044])
# torch.Size([1, 17, 24, 103, 2]) torch.Size([1])
# tensor([13.7220])
# torch.Size([1, 12, 29, 463, 2]) torch.Size([1])
# tensor([9.9354])
# torch.Size([1, 6, 5, 299, 2]) torch.Size([1])
# tensor([18.6089])
# torch.Size([1, 3, 31, 436, 2]) torch.Size([1])
# tensor([9.4477])
# torch.Size([1, 4, 4, 298, 2]) torch.Size([1])
# tensor([13.1098])
# torch.Size([1, 5, 12, 563, 2]) torch.Size([1])
# tensor([4.1959])
# torch.Size([1, 29, 23, 457, 2]) torch.Size([1])
# tensor([14.0309])
# torch.Size([1, 3, 4, 300, 2]) torch.Size([1])
# tensor([5.1836])
# torch.Size([1, 8, 7, 59, 2]) torch.Size([1])
# tensor([12.3124])
# torch.Size([1, 7, 7, 239, 2]) torch.Size([1])
# tensor([8.3742])
# torch.Size([1, 18, 11, 714, 2]) torch.Size([1])
# tensor([12.2660])
# torch.Size([1, 7, 14, 121, 2]) torch.Size([1])
# tensor([6.0413])
# torch.Size([1, 14, 61, 606, 2]) torch.Size([1])
# tensor([13.6872])
# torch.Size([1, 3, 7, 179, 2]) torch.Size([1])
# tensor([5.3421])
# torch.Size([1, 24, 17, 357, 2]) torch.Size([1])
# tensor([8.6603])
# torch.Size([1, 3, 45, 369, 2]) torch.Size([1])
# tensor([14.3123])
# torch.Size([1, 8, 8, 240, 2]) torch.Size([1])

# %%
class AsteroidLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, dropout=0.2):
        super(AsteroidLSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x: torch.Tensor):
        # Reshape x to (batch_size * num_sessions, num_lightcurves, input_size)
        batch_size, num_sessions, num_lightcurves, num_points, num_features = x.size()
        
        # Flatten the num_points dimension while keeping the last dimension as input_size
        x = x.view(batch_size * num_sessions, num_lightcurves * num_points, num_features)

        # Pass through LSTM
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
 
        out, _ = self.lstm(x, (h0, c0))

        # Take the output from the last time step
        out = out[:, -1, :]

        # Reshape to (batch_size, num_sessions, hidden_size)
        out = out.view(batch_size, num_sessions, -1)

        # Aggregate the session outputs (e.g., mean)
        out = torch.mean(out, dim=1)

        # Pass through the fully connected layer
        out = self.fc(out)

        return out

# %%
input_size = 2  # JD and brightness
hidden_size = 128
num_layers = 4
dropout = 0.2

# %%
model = AsteroidLSTM(input_size, hidden_size, num_layers)#.cuda()
model
# Out:
# AsteroidLSTM(
#   (lstm): LSTM(2, 128, num_layers=4, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)


def train_model(
    model: nn.Module,
    data_loader: DataLoader,
    optimizer: torch.optim.Optimizer,
    criterion: nn.MSELoss, 
    num_epochs: int,
    save_path: Path,
):
    model.train()
    best_loss = float("inf")

    for epoch in range(num_epochs):
        for inputs, targets in data_loader:
            #inputs, targets = inputs.cuda(), targets.cuda()

            outputs = model(inputs)
            loss = criterion(outputs, targets.view(-1, 1))

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        scheduler.step()
        print(f"Epoch [{epoch+1}/100], Loss: {loss.item():.4f}")

        if loss.item() < best_loss:
            best_loss = loss.item()
            torch.save(model.state_dict(), save_path)
            print(f"Model saved with loss {best_loss:.4f}")

# %%
save_path = MODELS_DIR / f"asteroid_lstm_{datetime.now().strftime('%Y%m%d_%H%M%S')}.pt"

train_model(model, data_loader, optimizer, criterion, num_epochs=100, save_path=save_path)
# Out:
# Epoch [1/100], Loss: 12.3935
# Model saved with loss 12.3935
# Epoch [2/100], Loss: 10.5926
# Model saved with loss 10.5926
# Epoch [3/100], Loss: 10.3596
# Model saved with loss 10.3596
# Epoch [4/100], Loss: 10.3191
# Model saved with loss 10.3191
# Epoch [5/100], Loss: 10.3019
# Model saved with loss 10.3019
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 3
#       1 save_path = MODELS_DIR / f"asteroid_lstm_{datetime.now().strftime('%Y%m%d_%H%M%S')}.pt"
# ----> 3 train_model(model, data_loader, optimizer, criterion, num_epochs=100, save_path=save_path)
#
# Cell In[19], line 25, in train_model(model, data_loader, optimizer, criterion, num_epochs, save_path)
#      22     loss = criterion(outputs, targets.view(-1, 1))
#      24     optimizer.zero_grad()
# ---> 25     loss.backward()
#      26     optimizer.step()
#      28 scheduler.step()
#
# File ~/miniforge3/envs/mgr/lib/python3.11/site-packages/torch/_tensor.py:525, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     515 if has_torch_function_unary(self):
#     516     return handle_torch_function(
#     517         Tensor.backward,
#     518         (self,),
#    (...)
#     523         inputs=inputs,
#     524     )
# --> 525 torch.autograd.backward(
#     526     self, gradient, retain_graph, create_graph, inputs=inputs
#     527 )
#
# File ~/miniforge3/envs/mgr/lib/python3.11/site-packages/torch/autograd/__init__.py:267, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     262     retain_graph = create_graph
#     264 # The reason we repeat the same comment below is that
#     265 # some Python versions print out the first line of a multi-line function
#     266 # calls in the traceback and some print out the last line
# --> 267 _engine_run_backward(
#     268     tensors,
#     269     grad_tensors_,
#     270     retain_graph,
#     271     create_graph,
#     272     inputs,
#     273     allow_unreachable=True,
#     274     accumulate_grad=True,
#     275 )
#
# File ~/miniforge3/envs/mgr/lib/python3.11/site-packages/torch/autograd/graph.py:744, in _engine_run_backward(t_outputs, *args, **kwargs)
#     742     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     743 try:
# --> 744     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     745         t_outputs, *args, **kwargs
#     746     )  # Calls into the C++ engine to run the backward pass
#     747 finally:
#     748     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
test_asteroids

# %%
# save_path = MODELS_DIR / "asteroid_lstm_20240516_005338.pt"

# %%
dataset = AsteroidDataset(test_asteroids)
test_loader = DataLoader(dataset, batch_size=1, collate_fn=collate_fn)

best_model = AsteroidLSTM(input_size, hidden_size, num_layers, dropout)
best_model.load_state_dict(torch.load(save_path))

for ind, batch in enumerate(test_loader):
    inputs, targets = batch

    predictions = best_model(inputs)
    print(f"{test_asteroids[ind].name} predicted period: {predictions.item():.4f} - true period: {targets.item():.4f}")

# %%
raise

# %%
def predict_model(model, data_loader):
    model.eval()  # Set the model to evaluation mode
    predictions = []
    with torch.no_grad():  # No need to track gradients for predictions
        for sessions, _ in data_loader:
            outputs = model(sessions)  # Assuming sessions are formatted correctly
            predictions.extend(outputs.detach().cpu().numpy())  # Store predictions
    

    return sum(predictions) / len(predictions)

# %%
data_loader = DataLoader(dataset, batch_size=1, collate_fn=collate_fn, shuffle=False)

# %%
predicted_period, = predict_model(model, data_loader)
true_period = dataset.periods[0]

print(f"True period: {true_period:.2f} hours")
print(f"Predicted period: {predicted_period:.2f} hours")
