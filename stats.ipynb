# %%
from src.utils import AsteroidLoader, LightcurveBinner, LightcurvePlotter

# %%
asteroid_loader = AsteroidLoader()
lightcurve_binner = LightcurveBinner()
lightcurve_plotter = LightcurvePlotter()

# %%
asteroids = [
    asteroid_loader.load_asteroid(name) for name in asteroid_loader.available_asteroids
]
asteroids
# Out:
# [Asteroid(id=91, name=Aegina, period=6.02817, lightcurves=2),
#  Asteroid(id=47, name=Aglaja, period=13.17707, lightcurves=2),
#  Asteroid(id=54, name=Alexandra, period=7.02264, lightcurves=38),
#  Asteroid(id=82, name=Alkmene, period=13.00079, lightcurves=16),
#  Asteroid(id=29, name=Amphitrite, period=5.39012, lightcurves=66),
#  Asteroid(id=64, name=Angelina, period=8.75033, lightcurves=22),
#  Asteroid(id=95, name=Arethusa, period=8.70221, lightcurves=5),
#  Asteroid(id=43, name=Ariadne, period=5.761987, lightcurves=43),
#  Asteroid(id=67, name=Asia, period=15.8515, lightcurves=2),
#  Asteroid(id=5, name=Astraea, period=16.80059, lightcurves=25),
#  Asteroid(id=36, name=Atalante, period=9.92692, lightcurves=31),
#  Asteroid(id=94, name=Aurora, period=7.226189, lightcurves=22),
#  Asteroid(id=63, name=Ausonia, period=9.29759, lightcurves=16),
#  Asteroid(id=83, name=Beatrix, period=10.1107, lightcurves=1),
#  Asteroid(id=28, name=Bellona, period=15.70785, lightcurves=24),
# ...

# %%
lightcurve_plotter.plot_lightcurves(asteroids[0].lightcurves)

# %%
eros = asteroid_loader.load_asteroid("Eros")

# %%
from lightkurve import LightCurve

from src.model.enums import EnumSortOptions

# %%
lc_long = eros.get_longest_lightcurve(by=EnumSortOptions.PERIOD)
lc_first = eros.lightcurves[0]

# %%
lightcurve_plotter.plot_lightcurve(lc_long)

# %%
lightcurve_plotter.plot_lightcurve(lc_first)

# %%
lc_k = LightCurve(time=lc_long.time_arr, flux=lc_long.brightness_arr)
lc_k
# Out:
# <LightCurve length=98>
#      time        flux   flux_err
#
#      Time      float64  float64
# -------------- -------- --------
#  2442397.67913 1.298972      nan
#  2442397.68138 1.339059      nan
# 2442397.686213 1.357688      nan
#  2442397.69038 1.374041      nan
# 2442397.696338 1.368988      nan
# 2442397.700047 1.350205      nan
# 2442397.707922 1.253141      nan
# 2442397.710672 1.218989      nan
# 2442397.716131 1.158777      nan
#            ...      ...      ...
#  2442398.00297 1.202264      nan
#  2442398.00747 1.314619      nan
# 2442398.010554 1.384203      nan
# 2442398.012804 1.434828      nan
#  2442398.01697 1.460158      nan
# 2442398.020845 1.472312      nan
# 2442398.023429 1.442779      nan
# 2442398.028387 1.434828      nan
# 2442398.032096 1.415141      nan

# %%
lc_k.scatter()
# Out:
# <Axes: xlabel='Time [JD]', ylabel='Flux'>

# %%
lc_k.remove_outliers(sigma=2).scatter()
# Out:
# <Axes: xlabel='Time [JD]', ylabel='Flux'>

# %%
lc_k = LightCurve(time=lc_first.time_arr, flux=lc_first.brightness_arr)
lc_k
# Out:
# <LightCurve length=21>
#      time         flux   flux_err
#
#      Time       float64  float64
# -------------- --------- --------
# 2433915.385708  1.021246      nan
# 2433915.401167  1.018429      nan
# 2433915.407583  1.030696      nan
# 2433915.423333  1.025016      nan
#    2433915.434  1.008163      nan
# 2433915.443625 0.9897614      nan
# 2433915.453542 0.9469576      nan
# 2433915.458333 0.9211503      nan
# 2433915.464125 0.9010119      nan
#            ...       ...      ...
# 2433915.496958  1.035453      nan
#  2433915.51175  1.071348      nan
#  2433915.51675  1.024072      nan
# 2433915.525583  1.038318      nan
# 2433915.533708  1.021246      nan
# 2433915.573625 0.9548398      nan
#  2433915.58325 0.9478302      nan
#  2433915.58975  1.020306      nan
# 2433915.609083  1.093278      nan

# %%
lc_k.scatter()
# Out:
# <Axes: xlabel='Time [JD]', ylabel='Flux'>

# %%
lc_k.remove_outliers(sigma=2).scatter()
# Out:
# <Axes: xlabel='Time [JD]', ylabel='Flux'>
