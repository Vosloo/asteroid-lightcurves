# %%
from src.utils import (
    AsteroidLoader,
    LightcurveBinner,
    LightcurvePlotter,
    LightcurveSplitter,
)

# %%
asteroid_loader = AsteroidLoader()
lightcurve_binner = LightcurveBinner()
lightcurve_plotter = LightcurvePlotter()
lightcurve_splitter = LightcurveSplitter()

# %%
asteroids = [
    asteroid_loader.load_asteroid(name) for name in asteroid_loader.available_asteroids
]
asteroids
# Out:
# [Asteroid(id=91, name=Aegina, period=6.02817, lightcurves=2),
#  Asteroid(id=47, name=Aglaja, period=13.17707, lightcurves=2),
#  Asteroid(id=54, name=Alexandra, period=7.02264, lightcurves=38),
#  Asteroid(id=82, name=Alkmene, period=13.00079, lightcurves=16),
#  Asteroid(id=29, name=Amphitrite, period=5.39012, lightcurves=66),
#  Asteroid(id=64, name=Angelina, period=8.75033, lightcurves=22),
#  Asteroid(id=95, name=Arethusa, period=8.70221, lightcurves=5),
#  Asteroid(id=43, name=Ariadne, period=5.761987, lightcurves=43),
#  Asteroid(id=67, name=Asia, period=15.8515, lightcurves=2),
#  Asteroid(id=5, name=Astraea, period=16.80059, lightcurves=25),
#  Asteroid(id=36, name=Atalante, period=9.92692, lightcurves=31),
#  Asteroid(id=94, name=Aurora, period=7.226189, lightcurves=22),
#  Asteroid(id=63, name=Ausonia, period=9.29759, lightcurves=16),
#  Asteroid(id=83, name=Beatrix, period=10.1107, lightcurves=1),
#  Asteroid(id=28, name=Bellona, period=15.70785, lightcurves=24),
# ...

# %%
asteroid = asteroids[1]

# %%
splitted = lightcurve_splitter.split_lightcurves(asteroid.lightcurves, max_time_diff=30)
splitted
# Out:
# [Lightcurve(id=15804, period=358.32499h scale=0, points_count=4),
#  Lightcurve(id=15804, period=0.00000h scale=0, points_count=1),
#  Lightcurve(id=15804, period=342.13375h scale=0, points_count=6),
#  Lightcurve(id=15804, period=252.13562h scale=0, points_count=4),
#  Lightcurve(id=15804, period=1.77598h scale=0, points_count=2),
#  Lightcurve(id=15804, period=390.07560h scale=0, points_count=3),
#  Lightcurve(id=15804, period=1.77619h scale=0, points_count=2),
#  Lightcurve(id=15804, period=1.77600h scale=0, points_count=2),
#  Lightcurve(id=15805, period=718.18699h scale=0, points_count=8),
#  Lightcurve(id=15805, period=717.73133h scale=0, points_count=16),
#  Lightcurve(id=15805, period=621.87938h scale=0, points_count=5),
#  Lightcurve(id=15805, period=0.00000h scale=0, points_count=1),
#  Lightcurve(id=15805, period=335.08459h scale=0, points_count=4),
#  Lightcurve(id=15805, period=693.91634h scale=0, points_count=12),
# ...

# %%
bins = lightcurve_binner.bin_lightcurves(splitted, max_time_diff=30, min_bin_size=2)
bins
# Out:
# [[Lightcurve(id=15804, period=1.77600h scale=0, points_count=2),
#   Lightcurve(id=15805, period=718.18699h scale=0, points_count=8),
#   Lightcurve(id=15805, period=717.73133h scale=0, points_count=16),
#   Lightcurve(id=15805, period=621.87938h scale=0, points_count=5),
#   Lightcurve(id=15805, period=0.00000h scale=0, points_count=1),
#   Lightcurve(id=15805, period=335.08459h scale=0, points_count=4),
#   Lightcurve(id=15805, period=693.91634h scale=0, points_count=12),
#   Lightcurve(id=15805, period=717.78907h scale=0, points_count=8),
#   Lightcurve(id=15805, period=454.80701h scale=0, points_count=5),
#   Lightcurve(id=15805, period=47.89094h scale=0, points_count=3),
#   Lightcurve(id=15805, period=0.00000h scale=0, points_count=1),
#   Lightcurve(id=15805, period=577.79791h scale=0, points_count=7),
#   Lightcurve(id=15805, period=576.77345h scale=0, points_count=5),
#   Lightcurve(id=15805, period=574.20394h scale=0, points_count=8),
# ...

# %%
bins[0][0].first_JD, bins[0][1].last_JD, bins[0][1].last_JD - bins[0][0].first_JD
# Out:
# (2457514.265954, 2450937.92116, -6576.344794000033)

# %%
lightcurve_plotter.plot_lightcurves(splitted)

# %%
for _bin in bins:
    lightcurve_plotter.plot_phased_lightcurves(_bin, period=asteroid.period)
